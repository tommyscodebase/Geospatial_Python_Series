# %% [markdown]
# # Interactive GeoVisualization (Introduction to Folium)

# %% [markdown]
# ## Creating a simple map

# %%
import folium

m = folium.Map(location=[6, -1], zoom_start=3)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5eb3cf26bada73db14822035fee0ffb7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5eb3cf26bada73db14822035fee0ffb7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5eb3cf26bada73db14822035fee0ffb7 = L.map(
#                 &quot;map_5eb3cf26bada73db14822035fee0ffb7&quot;,
#                 {
#                     center: [6.0, -1.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f69e15f75736e485f0ff15a6e6a151f8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5eb3cf26bada73db14822035fee0ffb7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
polygon_coord = [
    [6.21, -1.13],
    [6.29, -0.98],
    [6.18, -0.87],
    [6.09, -0.99],
    [6.06, -1.12],
    [6.14, -1.17],
    [6.21, -1.13]
]

line_coord = [
    [6.15, -1.24], [6.25, -1.13],
    [6.24, -0.98], [6.32, -0.85]
]

point_coords = [
    [6.07, -1.15], [6.13, -1.08], 
    [6.02, -0.96], [6.01, -1.07], [6.15, -0.93]
]

# %% [markdown]
# ## Adding Points, Lines and Polygons

# %%
import folium

m = folium.Map(location=point_coords[0])

# Adding a Point (marker)
popup_text = "<h1 style='color: red'> Heyy, you clicked me!!</h1>"
folium.Marker(
    location=point_coords[0],
    tooltip="Click me",
    popup=popup_text
).add_to(m)


# Adding a Line (Polyline)
folium.PolyLine(
    locations=line_coord,
    color="red"
).add_to(m)


# Adding a Polygon
folium.Polygon(
    locations=polygon_coord,
    fill=True,
    fill_color="red",
    fill_opacity=1
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e6ac208094af10f59cd6eb44c7ba888 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e6ac208094af10f59cd6eb44c7ba888&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e6ac208094af10f59cd6eb44c7ba888 = L.map(
#                 &quot;map_7e6ac208094af10f59cd6eb44c7ba888&quot;,
#                 {
#                     center: [-1.15, 6.07],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_546dd632015a83beb93dc5d121031633 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e6ac208094af10f59cd6eb44c7ba888);
#
#
#             var marker_bc37c9edd1f3203a8ac9449e4019d88d = L.marker(
#                 [-1.15, 6.07],
#                 {}
#             ).addTo(map_7e6ac208094af10f59cd6eb44c7ba888);
#
#
#         var popup_3cf3170dcea58c7bf27e25b6e28c1498 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_49ac00c571b348f0cccd2a54a75d526a = $(`&lt;div id=&quot;html_49ac00c571b348f0cccd2a54a75d526a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h1 style=&#x27;color: red&#x27;&gt; Heyy, you clicked me!!&lt;/h1&gt;&lt;/div&gt;`)[0];
#                 popup_3cf3170dcea58c7bf27e25b6e28c1498.setContent(html_49ac00c571b348f0cccd2a54a75d526a);
#
#
#
#         marker_bc37c9edd1f3203a8ac9449e4019d88d.bindPopup(popup_3cf3170dcea58c7bf27e25b6e28c1498)
#         ;
#
#
#
#
#             marker_bc37c9edd1f3203a8ac9449e4019d88d.bindTooltip(
#                 `&lt;div&gt;
#                      Click me
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_e1c1c1f13bd2e277076802e0a5cf9fac = L.polyline(
#                 [[-1.24, 6.15], [-1.13, 6.25], [-0.98, 6.24], [-0.85, 6.32]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7e6ac208094af10f59cd6eb44c7ba888);
#
#
#             var polygon_66f79d237783ab9a5be0af6068fe3412 = L.polygon(
#                 [[-1.13, 6.21], [-0.98, 6.29], [-0.87, 6.18], [-0.99, 6.09], [-1.12, 6.06], [-1.17, 6.14], [-1.13, 6.21]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7e6ac208094af10f59cd6eb44c7ba888);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Plotting a GeoJson

# %%
import os
import folium
import json


# Read the file
file_path = os.path.join(os.getcwd(), "data", "05_data", "west_africa.geojson")

with open(file_path, "r") as file:
    geo_data = json.load(file)


m = folium.Map(location=[13, -1], zoom_start=4)

folium.GeoJson(
    data=geo_data,
    zoom_on_click=True,
    style_function=lambda x: {
        "fillColor": "red",
        "fillOpacity": 0.8
    },
    popup=folium.GeoJsonPopup(fields=["name"])
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a409c4fc95a568b0a5cab432541aaeb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a409c4fc95a568b0a5cab432541aaeb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a409c4fc95a568b0a5cab432541aaeb = L.map(
#                 &quot;map_6a409c4fc95a568b0a5cab432541aaeb&quot;,
#                 {
#                     center: [13.0, -1.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15610f0c316551f83ab9a33fe3b2e38c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6a409c4fc95a568b0a5cab432541aaeb);
#
#
#         function geo_json_0aca584b6dbe543b0449f93d5ba3acd6_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.8};
#             }
#         }
#
#         function geo_json_0aca584b6dbe543b0449f93d5ba3acd6_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     if (typeof e.target.getBounds === &#x27;function&#x27;) {
#                         map_6a409c4fc95a568b0a5cab432541aaeb.fitBounds(e.target.getBounds());
#                     }
#                     else if (typeof e.target.getLatLng === &#x27;function&#x27;){
#                         let zoom = map_6a409c4fc95a568b0a5cab432541aaeb.getZoom()
#                         zoom = zoom &gt; 12 ? zoom : zoom + 1
#                         map_6a409c4fc95a568b0a5cab432541aaeb.flyTo(e.target.getLatLng(), zoom)
#                     }
#                 }
#             });
#         };
#         var geo_json_0aca584b6dbe543b0449f93d5ba3acd6 = L.geoJson(null, {
#                 onEachFeature: geo_json_0aca584b6dbe543b0449f93d5ba3acd6_onEachFeature,
#
#                 style: geo_json_0aca584b6dbe543b0449f93d5ba3acd6_styler,
#         });
#
#         function geo_json_0aca584b6dbe543b0449f93d5ba3acd6_add (data) {
#             geo_json_0aca584b6dbe543b0449f93d5ba3acd6
#                 .addData(data)
#                 .addTo(map_6a409c4fc95a568b0a5cab432541aaeb);
#         }
#             geo_json_0aca584b6dbe543b0449f93d5ba3acd6_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-16.71372880702347, 13.594958604379855], [-17.126106736712615, 14.373515733289224], [-17.62504269049066, 14.729540513564073], [-17.18517289882223, 14.919477240452862], [-16.700706346085923, 15.621527411354108], [-16.463098110407884, 16.13503611903846], [-16.12069007004193, 16.455662543193384], [-15.623666144258692, 16.369337063049812], [-15.135737270558819, 16.587282416240782], [-14.577347581428981, 16.59826365810281], [-14.099521450242179, 16.304302273010492], [-13.435737677453062, 16.03938304286619], [-12.830658331747516, 15.303691514542948], [-12.170750291380301, 14.616834214735505], [-12.12488745772126, 13.994727484589788], [-11.927716030311615, 13.422075100147396], [-11.55339779300543, 13.141213690641067], [-11.467899135778524, 12.754518947800975], [-11.51394283695059, 12.442987575729418], [-11.658300950557932, 12.386582749882836], [-12.203564825885634, 12.465647691289405], [-12.27859900557344, 12.354440008997287], [-12.499050665730564, 12.332089952031057], [-13.217818162478238, 12.575873521367967], [-13.700476040084325, 12.586182969610194], [-15.54847693527401, 12.628170070847347], [-15.816574266004254, 12.515567124883347], [-16.147716844130585, 12.547761542201187], [-16.677451951554573, 12.384851589401052], [-16.841524624081273, 13.15139394780256], [-15.931295945692211, 13.130284125211332], [-15.691000535534995, 13.270353094938457], [-15.511812506562933, 13.278569647672867], [-15.141163295949468, 13.509511623585238], [-14.712197231494628, 13.298206691943777], [-14.277701788784555, 13.280585028532244], [-13.844963344772408, 13.505041612192002], [-14.046992356817482, 13.79406789800045], [-14.376713833055788, 13.625680243377374], [-14.687030808968487, 13.630356960499784], [-15.08173539881382, 13.876491807505985], [-15.39877031092446, 13.860368

# %% [markdown]
# ## Adding layers and layergroups

# %%
import os
import json
import folium


m = folium.Map(location=point_coords[0])

# Add map tile layers
folium.TileLayer(tiles="OpenStreetMap", name="OSM").add_to(m)
folium.TileLayer(tiles="CartodbPositron", name="Carto DB").add_to(m)


# Point group
point_group = folium.FeatureGroup(name="Points", show=False).add_to(m)
for idx, point in enumerate(point_coords):
    folium.Marker(location=point, popup=f"Point {idx + 1}").add_to(point_group)


# Adding Line Group
line_group = folium.FeatureGroup(name="Lines", show=False).add_to(m)
folium.PolyLine(
    locations=line_coord,
    color="blue",
    weight=2.5,
    opacity=1
).add_to(line_group)


# Adding Polygon Group
polygon_group = folium.FeatureGroup(name="Polygons", show=False).add_to(m)
folium.Polygon(
    locations=polygon_coord,
    color="green",
    fill=True,
    fill_opacity=0.5
).add_to(polygon_group)


# Adding a GeoJSON layer to the layergroup
# Read the file
file_path = os.path.join(os.getcwd(), "data", "05_data", "west_africa.geojson")

with open(file_path, "r") as file:
    geo_data = json.load(file)

countries_group = folium.FeatureGroup(name="Countries").add_to(m)
folium.GeoJson(
    data=geo_data,
    zoom_on_click=True,
).add_to(countries_group)


# Add layergroup to the map
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54f975b17fb7a2e7aadd8296e8298fb7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54f975b17fb7a2e7aadd8296e8298fb7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54f975b17fb7a2e7aadd8296e8298fb7 = L.map(
#                 &quot;map_54f975b17fb7a2e7aadd8296e8298fb7&quot;,
#                 {
#                     center: [-1.15, 6.07],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9065a8e79f7e4a5fde7c75d1cde80739 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_54f975b17fb7a2e7aadd8296e8298fb7);
#
#
#             var tile_layer_2dc371727e853cb0b296d7e22701f48a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_54f975b17fb7a2e7aadd8296e8298fb7);
#
#
#             var tile_layer_0299251d0de9e190254e62ba7553c0c6 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_54f975b17fb7a2e7aadd8296e8298fb7);
#
#
#             var feature_group_43f01d43bb68a601240863f309ea75c8 = L.featureGroup(
#                 {}
#             ).addTo(map_54f975b17fb7a2e7aadd8296e8298fb7);
#
#
#             var marker_aa33c8ee17d10690e7b0ca53457601fd = L.marker(
#                 [-1.15, 6.07],
#                 {}
#             ).addTo(feature_group_43f01d43bb68a601240863f309ea75c8);
#
#
#         var popup_0249a990047bc746eddef2b2f55d27a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d9b60067f98adc8ef1391255840ce3f = $(`&lt;div id=&quot;html_2d9b60067f98adc8ef1391255840ce3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 1&lt;/div&gt;`)[0];
#                 popup_0249a990047bc746eddef2b2f55d27a8.setContent(html_2d9b60067f98adc8ef1391255840ce3f);
#
#
#
#         marker_aa33c8ee17d10690e7b0ca53457601fd.bindPopup(popup_0249a990047bc746eddef2b2f55d27a8)
#         ;
#
#
#
#
#             var marker_406509e34b6bdd5fbd2e36460b0d405e = L.marker(
#                 [-1.08, 6.13],
#                 {}
#             ).addTo(feature_group_43f01d43bb68a601240863f309ea75c8);
#
#
#         var popup_2961215591eb43ea614226c782a8026a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_939b93adfd2e3fb659cba8cc9659c573 = $(`&lt;div id=&quot;html_939b93adfd2e3fb659cba8cc9659c573&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 2&lt;/div&gt;`)[0];
#                 popup_2961215591eb43ea614226c782a8026a.setContent(html_939b93adfd2e3fb659cba8cc9659c573);
#
#
#
#         marker_406509e34b6bdd5fbd2e36460b0d405e.bindPopup(popup_2961215591eb43ea614226c782a8026a)
#         ;
#
#
#
#
#             var marker_a6f5e770a5a121df5e41d088a5ab3526 = L.marker(
#                 [-0.96, 6.02],
#                 {}
#             ).addTo(feature_group_43f01d43bb68a601240863f309ea75c8);
#
#
#         var popup_f6beabc8a6e21bd37a66819f1f6ed3b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44236727052f651a50be49a743c91221 = $(`&lt;div id=&quot;html_44236727052f651a50be49a743c91221&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 3&lt;/div&gt;`)[0];
#                 popup_f6beabc8a6e21bd37a66819f1f6ed3b7.setContent(html_44236727052f651a50be49a743c91
